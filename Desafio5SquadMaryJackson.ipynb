# %% [markdown]
# <a href="https://colab.research.google.com/github/dsreliete/Womakerscode-DA-desafio_squad/blob/main/Desafio5SquadMaryJackson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np

# Definindo uma configuração personalizada para a exibição de dados
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
url = "https://raw.githubusercontent.com/dsreliete/Womakerscode-DA-desafio_squad/refs/heads/main/desafio_01_preco_imoveis.csv"
df = pd.read_csv(url)
df
# Out:
#                id             date        price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000 221900.00000         3    1.00000
# 1      6414100192  20141209T000000 538000.00000         3    2.25000
# 2      5631500400  20150225T000000 180000.00000         2    1.00000
# 3      2487200875  20141209T000000 604000.00000         4    3.00000
# 4      1954400510  20150218T000000 510000.00000         3    2.00000
# ...           ...              ...          ...       ...        ...
# 21608   263000018  20140521T000000 360000.00000         3    2.50000
# 21609  6600060120  20150223T000000 400000.00000         4    2.50000
# 21610  1523300141  20140623T000000 402101.00000         2    0.75000
# 21611   291310100  20150116T000000 400000.00000         3    2.50000
# 21612  1523300157  20141015T000000 325000.00000         2    0.75000
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180      5650 1.00000           0     0          3      7
# 1             2570      7242 2.00000           0     0          3      7
# 2              770     10000 1.00000           0     0          3      6
# 3             1960      5000 1.00000           0     0          5      7
# 4             1680      8080 1.00000           0     0          3      8
# ...            ...       ...     ...         ...   ...        ...    ...
# 21608         1530      1131 3.00000           0     0          3      8
# 21609         2310      5813 2.00000           0     0          3      8
# 21610         1020      1350 2.00000           0     0          3      7
# 21611         1600      2388 2.00000           0     0          3      8
# 21612         1020      1076 2.00000           0     0          3      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178 47.51120
# 1            2170            400      1951          1991    98125 47.72100
# 2             770              0      1933             0    98028 47.73790
# 3            1050            910      1965             0    98136 47.52080
# 4            1680              0      1987             0    98074 47.61680
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103 47.69930
# 21609        2310              0      2014             0    98146 47.51070
# 21610        1020              0      2009             0    98144 47.59440
# 21611        1600              0      2004             0    98027 47.53450
# 21612        1020              0      2008             0    98144 47.59410
#
#             long
# 0     -122.25700
# 1     -122.31900
# 2     -122.23300
# 3     -122.39300
# 4     -122.04500
# ...          ...
# 21608 -122.34600
# 21609 -122.36200
# 21610 -122.29900
# 21611 -122.06900
# 21612 -122.29900
#
# [21613 rows x 19 columns]

# %% [markdown]
# # **Desafio Análise de Correlação:**
#
# Suponha que você trabalha em uma empresa do setor imobiliário. Para essa empresa é muito importante precificar corretamente o imóvel, caso contrário, os corretores podem perder a venda. Como parte do time de dados, você é responsável por analisar os principais fatores que podem afetar o preço dos imóveis. Para isso, eles te enviaram a base de dados (desafio_01_preco_imoveis.csv). Como você poderia ajudá-los?

# %% [markdown]
# 1 - Analise a correlação de todas as variáveis com o preço do imóvel. Quais variáveis são mais correlacionadas? Quais são menos correlacionadas?

# %%
# Convertendo a coluna 'date' para o tipo datetime, para garantir que a coluna de data seja interpretada corretamente pelo pandas
df['date'] = pd.to_datetime(df['date'], format='%Y%m%dT%H%M%S')

# %%
# Calculando a correlação entre todas as variáveis do DataFrame
corr = df.corr()

# Gerando um mapa de calor para visualizar as correlações entre as variáveis
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a19da_row0_col0, #T_a19da_row1_col1, #T_a19da_row2_col2, #T_a19da_row3_col3, #T_a19da_row4_col4, #T_a19da_row5_col5, #T_a19da_row6_col6, #T_a19da_row7_col7, #T_a19da_row8_col8, #T_a19da_row9_col9, #T_a19da_row10_col10, #T_a19da_row11_col11, #T_a19da_row12_col12, #T_a19da_row13_col13, #T_a19da_row14_col14, #T_a19da_row15_col15, #T_a19da_row16_col16, #T_a19da_row17_col17, #T_a19da_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a19da_row0_
{
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_a19da_row2_col10, #T_a19da_row10_col18 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_a19da_row2_col11, #T_a19da_row11_col4 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_a19da_row2_col12, #T_a19da_row11_col2 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_a19da_row2_col13, #T_a19da_row3_col11 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_a19da_row2_col14, #T_a19da_row11_col9, #T_a19da_row18_col7 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_a19da_row2_col15, #T_a19da_row3_col10, #T_a19da_row17_col13 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_a19da_row2_col16, #T_a19da_row9_col4 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_a19da_row2_col17, #T_a19da_row13_col3 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_a19da_row3_col2, #T_a19da_row9_col12, #T_a19da_row17_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_a19da_row3_col4 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_a19da_row3_col5 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_a19da_row3_col6, #T_a19da_row3_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_a19da_row3_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_a19da_row3_col12, #T_a19da_row7_col4 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_a19da_row3_col14 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_a19da_row3_col18, #T_a19da_row11_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_a19da_row4_col1, #T_a19da_row5_col1, #T_a19da_row13_col7, #T_a19da_row14_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_a19da_row4_col2 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_a19da_row4_col3, #T_a19da_row12_col18 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_a19da_row4_col5, #T_a19da_row5_col4, #T_a19da_row12_col11 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_a19da_row4_col7 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_a19da_row4_col11, #T_a19da_row5_col2 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_a19da_row4_col13 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_a19da_row4_col14 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_a19da_row4_col17, #T_a19da_row12_col10, #T_a19da_row15_col3, #T_a19da_row16_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_a19da_row4_col18 {
#   background-color: #dddcdc;
#   color: #000000;

# %%
# Ordenando os valores de correlação da variável 'price' de forma decrescente
corr["price"].sort_values(ascending = False)
# Out:
# price            1.00000
# sqft_living      0.70204
# grade            0.66743
# sqft_above       0.60557
# bathrooms        0.52514
# view             0.39729
# sqft_basement    0.32382
# bedrooms         0.30835
# lat              0.30700
# waterfront       0.26637
# floors           0.25679
# yr_renovated     0.12643
# sqft_lot         0.08966
# yr_built         0.05401
# condition        0.03636
# long             0.02163
# date            -0.00436
# id              -0.01676
# zipcode         -0.05320
# Name: price, dtype: float64

# %% [markdown]
# ## Resultados da análise:
# As 5 variáveis mais correlacionadas positivamente com o preço do imóvel são:
#
# * sqft_living, (área útil do imóvel)
# * grade, (qualidade do design e construção)
# * sqft_above, (área útil acima do solo)
# * bathrooms, (número de banheiros)
# * view. (vista que o imóvel oferece)

# %% [markdown]
# As 5 variáveis menos correlacionadas com o preço são:
#
# * id (identificação única do imóvel)
# * zipcode (código postal)
# * long (longitude)
# * condition (condição do imóvel)
# * yr_built (ano de construção)

# %% [markdown]
# ## Conclusão
# Na matriz de correlação acima, podemos identificar, por meio do mapa de calor, as variáveis mais correlacionadas, as menos correlacionadas e as neutras.
#
# * **Correlação positiva**: Quanto mais próximo de 1, mais forte é a correlação positiva, o que é indicado pela cor vermelha. Isso significa que as variáveis aumentam juntas. Um exemplo é a correlação entre sqft_living e sqft_above.
#
# * **Correlação neutra**: Valores próximos de 0 indicam pouca ou nenhuma correlação, representados pela cor branca. Um exemplo disso é a relação entre zipcode e lat, onde praticamente não há impacto entre essas variáveis.
#
# * **Correlação negativa**: Valores próximos de -1 indicam uma correlação negativa, mostrada pela cor azul escura, o que significa que uma variável tende a diminuir à medida que a outra aumenta. Um exemplo disso é a correlação entre condition e yr_built.

# %% [markdown]
# 2 - Para as top 5 variáveis mais correlacionadas com o preço:
# 1. plote as suas distribuições (histograma e boxplot)

# %% [markdown]
# 2. plote o scatterplot (gráfico de dispersão), contendo preço no eixo Y e a variável correlacionada no eixo X.

# %% [markdown]
# 3. para cada uma das 5 variáveis faça uma regressão linear simples sendo preciso a variável resposta (y) e interprete os resultados.
