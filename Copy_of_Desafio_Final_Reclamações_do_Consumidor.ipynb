# %% [markdown]
# <a href="https://colab.research.google.com/github/dsreliete/Womakerscode-DA-desafio_squad/blob/main/Copy_of_Desafio_Final_Reclama%C3%A7%C3%B5es_do_Consumidor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Suponha que você trabalha na área de dados do Procon. Diariamente, você e sua equipe recebem dados de diversas reclamações dos consumidores. Cada reclamação, então, tem um determinado tempo para ser resolvida entre o cliente e a companhia em questão.
#
# Dado esse contexto, a sua equipe recebeu do time de operações dados históricos de reclamações de 2017 a 2021 na pasta reclamações-consumidor. Os dados são uma amostra dos dados extraídos do kaggle oriundos do Procon de 2017 a 2021.
#
#
# De posse dessas informações, a sua equipe ficou encarregada de responder às seguintes perguntas do time de negócios:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url_2017 = "https://raw.githubusercontent.com/dsreliete/Womakerscode-DA-desafio_squad/refs/heads/main/reclamacoes-fundamentadas-sindec-2017.csv"
url_2018 = "https://raw.githubusercontent.com/dsreliete/Womakerscode-DA-desafio_squad/refs/heads/main/reclamacoes-fundamentadas-sindec-2018.csv"
url_2019 = "https://raw.githubusercontent.com/dsreliete/Womakerscode-DA-desafio_squad/refs/heads/main/reclamacoes-fundamentadas-sindec-2019.csv"
url_2020 = "https://raw.githubusercontent.com/dsreliete/Womakerscode-DA-desafio_squad/refs/heads/main/reclamacoes-fundamentadas-sindec-2020.csv"
url_2021 = "https://raw.githubusercontent.com/dsreliete/Womakerscode-DA-desafio_squad/refs/heads/main/reclamacoes-fundamentadas-sindec-2021.csv"

reclamacoes2017 = pd.read_csv(url_2017, sep=';', on_bad_lines='warn')
reclamacoes2018 = pd.read_csv(url_2018, sep=';', on_bad_lines='warn')
reclamacoes2019 = pd.read_csv(url_2019, sep=';', on_bad_lines='warn')
reclamacoes2020 = pd.read_csv(url_2020, sep=';', on_bad_lines='warn')
reclamacoes2021 = pd.read_csv(url_2021, sep=';', on_bad_lines='warn')
# Out:
# <ipython-input-3-3cdfa4a4267b>:8: ParserWarning: Skipping line 3216: expected 23 fields, saw 24
# Skipping line 3238: expected 23 fields, saw 24
# Skipping line 12315: expected 23 fields, saw 25
# Skipping line 12407: expected 23 fields, saw 24
# Skipping line 17441: expected 23 fields, saw 24
# Skipping line 18208: expected 23 fields, saw 24
# Skipping line 19617: expected 23 fields, saw 24
# Skipping line 23141: expected 23 fields, saw 24
# Skipping line 23641: expected 23 fields, saw 24
# Skipping line 23642: expected 23 fields, saw 25
# Skipping line 27136: expected 23 fields, saw 24
# Skipping line 27661: expected 23 fields, saw 24
# Skipping line 28109: expected 23 fields, saw 24
#
#   reclamacoes2018 = pd.read_csv(url_2018, sep=';', on_bad_lines='warn')
# <ipython-input-3-3cdfa4a4267b>:9: ParserWarning: Skipping line 117: expected 23 fields, saw 25
# Skipping line 1205: expected 23 fields, saw 25
# Skipping line 1285: expected 23 fields, saw 24
# Skipping line 3596: expected 23 fields, saw 25
# Skipping line 4134: expected 23 fields, saw 24
# Skipping line 5483: expected 23 fields, saw 25
# Skipping line 8028: expected 23 fields, saw 24
# Skipping line 8307: expected 23 fields, saw 24
# Skipping line 8824: expected 23 fields, saw 25
# Skipping line 9516: expected 23 fields, saw 24
# Skipping line 9696: expected 23 fields, saw 24
# Skipping line 9698: expected 23 fields, saw 24
# Skipping line 10545: expected 23 fields, saw 25
# Skipping line 11232: expected 23 fields, saw 25
# Skipping line 11503: expected 23 fields, saw 25
# Skipping line 11548: expected 23 fields, saw 24
# Skipping line 11554: expected 23 fields, saw 25
# Skipping line 11703: expected 23 fields, saw 24
# Skipping line 12473: expected 23 fields, saw 24
# Skipping line 13879: expected 23 fields, saw 24
# Skipping line 16696: expected 23 fields, saw 24
# Skipping line 17302: expected 23 fields, saw 24
#
#   reclamacoes2019 = pd.read_csv(url_2019, sep=';', on_bad_lines='warn')
# <ipython-input-3-3cdfa4a4267b>:10: ParserWarning: Skipping line 1464: expected 23 fields, saw 25
# Skipping line 1526: expected 23 fields, saw 25
# Skipping line 1527: expected 23 fields, saw 25
# Skipping line 1748: expected 23 fields, saw 25
# Skipping line 1891: expected 23 fields, saw 25
# Skipping line 3177: expected 23 fields, saw 25
# Skipping line 6591: expected 23 fields, saw 25
# Skipping line 7369: expected 23 fields, saw 25
# Skipping line 7903: expected 23 fields, saw 25
# Skipping line 7904: expected 23 fields, saw 25
#
#   reclamacoes2020 = pd.read_csv(url_2020, sep=';', on_bad_lines='warn')

# %%
reclamacoes2017.head()
# Out:
#    2017  2017-10-05 09:48:39.000  2017-07-27 14:43:37.000  03  Sudeste  SP  \
# 0  2017  2017-12-12 12:35:53.000  2017-07-31 16:03:45.000   3  Sudeste  SP
# 1  2017  2017-12-12 12:40:07.000  2017-08-04 10:55:48.000   3  Sudeste  SP
# 2  2017  2017-10-26 14:07:56.000  2017-07-19 14:48:25.000   3  Sudeste  SP
# 3  2017  2017-12-04 09:51:45.000  2017-07-21 11:00:06.000   3  Sudeste  SP
# 4  2017  2017-10-26 14:09:00.000  2017-07-21 10:36:50.000   3  Sudeste  SP
#
#                                    ITAÚ UNIBANCO S/A  \
# 0                                          CLARO S/A
# 1  ELETROPAULO METROPOLITANA ELETRICIDADE DE S PAULO
# 2                            GNN GARAGENS LTDA - EPP
# 3                                          CLARO S/A
# 4              AEROVIAS DEL CONTINENTE AMERICANO S/A
#
#           BANCO ITAÚ/BANCO UNIBANCO  1  60701190000104  ...    6422100  \
# 0                               NET  1    4.043254e+13  ...        NaN
# 1         ELETROPAULO METROPOLITANA  1    6.169523e+13  ...  3514000.0
# 2                    NETPARK.COM.BR  1    7.155738e+12  ...  5223100.0
# 3  CLARO / NET / EMBRATEL / CLAROTV  1    4.043254e+13  ...  6120501.0
# 4             AVIANCA INTERNACIONAL  1    3.371284e+13  ...  5111100.0
#
#   BANCOS MÚLTIPLOS, COM CARTEIRA COMERCIAL  S   76  \
# 0                                      NaN  S  186
# 1         DISTRIBUIÇÃO DE ENERGIA ELÉTRICA  N  185
# 2               ESTACIONAMENTO DE VEÍCULOS  N  262
# 3                  TELEFONIA MÓVEL CELULAR  S  186
# 4  TRANSPORTE AÉREO DE PASSAGEIROS REGULAR  S  276
#
#                                     Outros Contratos    1112  \
# 0  Telefonia Fixa ( Plano de Expansão / Compra e ...  3844.0
# 1                                   Energia Elétrica  6030.0
# 2  Estacionamento ( Particular, Supermercado, Sho...  4946.0
# 3  Telefonia Fixa ( Plano de Expansão / Compra e ...  3624.0
# 4  Agências e Operadoras de viagens (pacotes turí...  5317.0
#
#    Contrato (não cumprimento, alteração, transferencia, irregularidade, rescisão, etc.)  \
# 0           Contrato - Rescisão/alteração unilateral
# 1       PID - Pedido de Indenização por Danos Morais
# 2  Vicio de qualidade (mal executado, inadequado,...
# 3  Vicio de qualidade (mal executado, inadequado,...
# 4  Desistência do serviço (artigo 49 - descumprim...
#
#    F  entre 31 a 40 anos    5057030
# 0  M     mais de 70 anos  4444000.0
# 1  F  entre 31 a 40 anos  4674110.0
# 2  M  entre 31 a 40 anos  2376040.0
# 3  M  entre 41 a 50 anos  2072002.0
# 4  M  entre 21 a 30 anos  4368003.0
#
# [5 rows x 23 columns]

# %%
reclamacoes2017.columns
# Out:
# Index(['2017', '2017-10-05 09:48:39.000', '2017-07-27 14:43:37.000', '03',
#        'Sudeste', 'SP', 'ITAÚ UNIBANCO S/A', 'BANCO ITAÚ/BANCO UNIBANCO', '1',
#        '60701190000104', '60701190', 'ITAU UNIBANCO S.A.', 'EST UNIF',
#        '6422100', 'BANCOS MÚLTIPLOS, COM CARTEIRA COMERCIAL', 'S', '76',
#        'Outros Contratos', '1112',
#        'Contrato (não cumprimento, alteração, transferencia, irregularidade, rescisão, etc.)',
#        'F', 'entre 31 a 40 anos', '5057030'],
#       dtype='object')

# %%
reclamacoes2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42306 entries, 0 to 42305
# Data columns (total 23 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   2017                                                                                  42306 non-null  int64
#  1   2017-10-05 09:48:39.000                                                               42300 non-null  object
#  2   2017-07-27 14:43:37.000                                                               42300 non-null  object
#  3   03                                                                                    42306 non-null  int64
#  4   Sudeste                                                                               42306 non-null  object
#  5   SP                                                                                    42306 non-null  object
#  6   ITAÚ UNIBANCO S/A                                                                     42305 non-null  object
#  7   BANCO ITAÚ/BANCO UNIBANCO                                                             35776 non-null  object
#  8   1                                                                                     42306 non-null  int64
#  9   60701190000104                                                                        39851 non-null  float64
#  10  60701190                                                                              39851 non-null  float64
#  11  ITAU UNIBANCO S.A.                                                                    37213 non-null  object
#  12  EST UNIF                                                                              19074 non-null  object
#  13  6422100                                                                               37213 non-null  float64
#  14  BANCOS MÚLTIPLOS, COM CARTEIRA COMERCIAL                                              36977 non-null  object
#  15  S                                                                                     42306 non-null  object
#  16  76                                                                                    42306 non-null  int64
#  17  Outros Contratos                                                                      42306 non-null  object
#  18  1112                                                                                  33370 non-null  float64
#  19  Contrato (não cumprimento, alteração, transferencia, irregularidade, rescisão, etc.)  33370 non-null  object
#  20  F                                                                                     42297 non-null  object
#  21  entre 31 a 40 anos                                                                    42306 non-null  object
#  22  5057030                                                                               37604 non-null  float64
# dtypes: float64(5), int64(4), object(14)
# memory usage: 7.4+ MB

# %%
# criando un novo df com os titulos da coluna None
newreclamacoes2017 = pd.read_csv(url_2017, sep=';', on_bad_lines='warn', header=None)
newreclamacoes2017.head()
# Out:
#      0                        1                        2   3        4   5   \
# 0  2017  2017-10-05 09:48:39.000  2017-07-27 14:43:37.000   3  Sudeste  SP
# 1  2017  2017-12-12 12:35:53.000  2017-07-31 16:03:45.000   3  Sudeste  SP
# 2  2017  2017-12-12 12:40:07.000  2017-08-04 10:55:48.000   3  Sudeste  SP
# 3  2017  2017-10-26 14:07:56.000  2017-07-19 14:48:25.000   3  Sudeste  SP
# 4  2017  2017-12-04 09:51:45.000  2017-07-21 11:00:06.000   3  Sudeste  SP
#
#                                                   6   \
# 0                                  ITAÚ UNIBANCO S/A
# 1                                          CLARO S/A
# 2  ELETROPAULO METROPOLITANA ELETRICIDADE DE S PAULO
# 3                            GNN GARAGENS LTDA - EPP
# 4                                          CLARO S/A
#
#                                  7   8             9   ...         13  \
# 0         BANCO ITAÚ/BANCO UNIBANCO   1  6.070119e+13  ...  6422100.0
# 1                               NET   1  4.043254e+13  ...        NaN
# 2         ELETROPAULO METROPOLITANA   1  6.169523e+13  ...  3514000.0
# 3                    NETPARK.COM.BR   1  7.155738e+12  ...  5223100.0
# 4  CLARO / NET / EMBRATEL / CLAROTV   1  4.043254e+13  ...  6120501.0
#
#                                          14 15   16  \
# 0  BANCOS MÚLTIPLOS, COM CARTEIRA COMERCIAL  S   76
# 1                                       NaN  S  186
# 2          DISTRIBUIÇÃO DE ENERGIA ELÉTRICA  N  185
# 3                ESTACIONAMENTO DE VEÍCULOS  N  262
# 4                   TELEFONIA MÓVEL CELULAR  S  186
#
#                                                   17      18  \
# 0                                   Outros Contratos  1112.0
# 1  Telefonia Fixa ( Plano de Expansão / Compra e ...  3844.0
# 2                                   Energia Elétrica  6030.0
# 3  Estacionamento ( Particular, Supermercado, Sho...  4946.0
# 4  Telefonia Fixa ( Plano de Expansão / Compra e ...  3624.0
#
#                                                   19 20                  21  \
# 0  Contrato (não cumprimento, alteração, transfer...  F  entre 31 a 40 anos
# 1           Contrato - Rescisão/alteração unilateral  M     mais de 70 anos
# 2       PID - Pedido de Indenização por Danos Morais  F  entre 31 a 40 anos
# 3  Vicio de qualidade (mal executado, inadequado,...  M  entre 31 a 40 anos
# 4  Vicio de qualidade (mal executado, inadequado,...  M  entre 41 a 50 anos
#
#           22
# 0  5057030.0
# 1  4444000.0
# 2  4674110.0
# 3  2376040.0
# 4  2072002.0
#
# [5 rows x 23 columns]

# %%
reclamacoes2018.head()
# Out:
#    AnoCalendario         DataArquivamento             DataAbertura  \
# 0           2018  2018-06-20 09:45:37.000  2018-02-19 09:25:45.000
# 1           2018  2018-06-20 09:45:37.000  2018-02-19 09:25:45.000
# 2           2018  2018-06-20 09:45:37.000  2018-02-19 09:25:45.000
# 3           2018  2018-08-29 08:47:27.000  2018-05-09 10:58:10.000
# 4           2018  2018-08-29 08:47:27.000  2018-05-09 10:58:10.000
#
#    CodigoRegiao    Regiao  UF  \
# 0             2  Nordeste  MA
# 1             2  Nordeste  MA
# 2             2  Nordeste  MA
# 3             2  Nordeste  MA
# 4             2  Nordeste  MA
#
#                                     strRazaoSocial        strNomeFantasia  \
# 0                       MOTOTEC SERVIÇOS LTDA - ME                MOTOTEC
# 1                             MAGAZINE LILIANI S/A                LILIANI
# 2              SAMSUNG ELETRÔNICA DA AMAZONIA LTDA                SAMSUNG
# 3  TECNO INDUSTRIA E COMERCIO DE COMPUTADORES LTDA                  IBYTE
# 4       SUPERTECH INFORMATICA - JC & CIA LTDA - ME  SUPERTECH INFORMATICA
#
#    Tipo    NumeroCNPJ  ...  CNAEPrincipal  \
# 0     1  8.852225e+12  ...      4752100.0
# 1     1  1.159030e+13  ...      4754701.0
# 2     1  2.802730e+11  ...      2632900.0
# 3     1  7.272825e+12  ...      4753900.0
# 4     1  9.632201e+12  ...      4751201.0
#
#                                    DescCNAEPrincipal Atendida  CodigoAssunto  \
# 0  COMÉRCIO VAREJISTA ESPECIALIZADO DE EQUIPAMENT...        S            101
# 1                       COMÉRCIO VAREJISTA DE MÓVEIS        S            101
# 2  FABRICAÇÃO DE APARELHOS TELEFÔNICOS E DE OUTRO...        S            101
# 3  COMÉRCIO VAREJISTA ESPECIALIZADO DE ELETRODOMÉ...        S             76
# 4                                                NaN        S             76
#
#                                     DescricaoAssunto CodigoProblema  \
# 0  Telefone ( Convencional, Celular, Interfone, E...            NaN
# 1  Telefone ( Convencional, Celular, Interfone, E...            NaN
# 2  Telefone ( Convencional, Celular, Interfone, E...            NaN
# 3                                   Outros Contratos            NaN
# 4                                   Outros Contratos            NaN
#
#    DescricaoProblema SexoConsumidor  FaixaEtariaConsumidor CEPConsumidor
# 0                NaN              F     entre 41 a 50 anos    65631110.0
# 1                NaN              F     entre 41 a 50 anos    65631110.0
# 2                NaN              F     entre 41 a 50 anos    65631110.0
# 3                NaN              F     entre 31 a 40 anos    65630020.0
# 4                NaN              F     entre 31 a 40 anos    65630020.0
#
# [5 rows x 23 columns]

# %%
reclamacoes2018.columns
# Out:
# Index(['AnoCalendario', 'DataArquivamento', 'DataAbertura', 'CodigoRegiao',
#        'Regiao', 'UF', 'strRazaoSocial', 'strNomeFantasia', 'Tipo',
#        'NumeroCNPJ', 'RadicalCNPJ', 'RazaoSocialRFB', 'NomeFantasiaRFB',
#        'CNAEPrincipal', 'DescCNAEPrincipal', 'Atendida', 'CodigoAssunto',
#        'DescricaoAssunto', 'CodigoProblema', 'DescricaoProblema',
#        'SexoConsumidor', 'FaixaEtariaConsumidor', 'CEPConsumidor'],
#       dtype='object')

# %%
reclamacoes2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39047 entries, 0 to 39046
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AnoCalendario          39047 non-null  int64
#  1   DataArquivamento       39033 non-null  object
#  2   DataAbertura           39046 non-null  object
#  3   CodigoRegiao           39047 non-null  int64
#  4   Regiao                 39047 non-null  object
#  5   UF                     39047 non-null  object
#  6   strRazaoSocial         39045 non-null  object
#  7   strNomeFantasia        32229 non-null  object
#  8   Tipo                   39047 non-null  int64
#  9   NumeroCNPJ             37729 non-null  float64
#  10  RadicalCNPJ            37609 non-null  float64
#  11  RazaoSocialRFB         34777 non-null  object
#  12  NomeFantasiaRFB        15650 non-null  object
#  13  CNAEPrincipal          34777 non-null  float64
#  14  DescCNAEPrincipal      34589 non-null  object
#  15  Atendida               39047 non-null  object
#  16  CodigoAssunto          39047 non-null  int64
#  17  DescricaoAssunto       39047 non-null  object
#  18  CodigoProblema         87 non-null     float64
#  19  DescricaoProblema      87 non-null     object
#  20  SexoConsumidor         39041 non-null  object
#  21  FaixaEtariaConsumidor  39047 non-null  object
#  22  CEPConsumidor          37188 non-null  float64
# dtypes: float64(5), int64(4), object(14)
# memory usage: 6.9+ MB

# %%
columns18 = reclamacoes2018.columns
columns18
# Out:
# Index(['AnoCalendario', 'DataArquivamento', 'DataAbertura', 'CodigoRegiao',
#        'Regiao', 'UF', 'strRazaoSocial', 'strNomeFantasia', 'Tipo',
#        'NumeroCNPJ', 'RadicalCNPJ', 'RazaoSocialRFB', 'NomeFantasiaRFB',
#        'CNAEPrincipal', 'DescCNAEPrincipal', 'Atendida', 'CodigoAssunto',
#        'DescricaoAssunto', 'CodigoProblema', 'DescricaoProblema',
#        'SexoConsumidor', 'FaixaEtariaConsumidor', 'CEPConsumidor'],
#       dtype='object')

# %%
newreclamacoes2017.columns = columns18
newreclamacoes2017.head()
# Out:
#    AnoCalendario         DataArquivamento             DataAbertura  \
# 0           2017  2017-10-05 09:48:39.000  2017-07-27 14:43:37.000
# 1           2017  2017-12-12 12:35:53.000  2017-07-31 16:03:45.000
# 2           2017  2017-12-12 12:40:07.000  2017-08-04 10:55:48.000
# 3           2017  2017-10-26 14:07:56.000  2017-07-19 14:48:25.000
# 4           2017  2017-12-04 09:51:45.000  2017-07-21 11:00:06.000
#
#    CodigoRegiao   Regiao  UF  \
# 0             3  Sudeste  SP
# 1             3  Sudeste  SP
# 2             3  Sudeste  SP
# 3             3  Sudeste  SP
# 4             3  Sudeste  SP
#
#                                       strRazaoSocial  \
# 0                                  ITAÚ UNIBANCO S/A
# 1                                          CLARO S/A
# 2  ELETROPAULO METROPOLITANA ELETRICIDADE DE S PAULO
# 3                            GNN GARAGENS LTDA - EPP
# 4                                          CLARO S/A
#
#                     strNomeFantasia  Tipo    NumeroCNPJ  ...  CNAEPrincipal  \
# 0         BANCO ITAÚ/BANCO UNIBANCO     1  6.070119e+13  ...      6422100.0
# 1                               NET     1  4.043254e+13  ...            NaN
# 2         ELETROPAULO METROPOLITANA     1  6.169523e+13  ...      3514000.0
# 3                    NETPARK.COM.BR     1  7.155738e+12  ...      5223100.0
# 4  CLARO / NET / EMBRATEL / CLAROTV     1  4.043254e+13  ...      6120501.0
#
#                           DescCNAEPrincipal Atendida  CodigoAssunto  \
# 0  BANCOS MÚLTIPLOS, COM CARTEIRA COMERCIAL        S             76
# 1                                       NaN        S            186
# 2          DISTRIBUIÇÃO DE ENERGIA ELÉTRICA        N            185
# 3                ESTACIONAMENTO DE VEÍCULOS        N            262
# 4                   TELEFONIA MÓVEL CELULAR        S            186
#
#                                     DescricaoAssunto CodigoProblema  \
# 0                                   Outros Contratos         1112.0
# 1  Telefonia Fixa ( Plano de Expansão / Compra e ...         3844.0
# 2                                   Energia Elétrica         6030.0
# 3  Estacionamento ( Particular, Supermercado, Sho...         4946.0
# 4  Telefonia Fixa ( Plano de Expansão / Compra e ...         3624.0
#
#                                    DescricaoProblema SexoConsumidor  \
# 0  Contrato (não cumprimento, alteração, transfer...              F
# 1           Contrato - Rescisão/alteração unilateral              M
# 2       PID - Pedido de Indenização por Danos Morais              F
# 3  Vicio de qualidade (mal executado, inadequado,...              M
# 4  Vicio de qualidade (mal executado, inadequado,...              M
#
#    FaixaEtariaConsumidor CEPConsumidor
# 0     entre 31 a 40 anos     5057030.0
# 1        mais de 70 anos     4444000.0
# 2     entre 31 a 40 anos     4674110.0
# 3     entre 31 a 40 anos     2376040.0
# 4     entre 41 a 50 anos     2072002.0
#
# [5 rows x 23 columns]

# %%
reclamacoes2019.head()
# Out:
#    AnoCalendario         DataArquivamento             DataAbertura  \
# 0           2019  2019-10-04 11:12:54.000  2019-09-02 09:27:15.000
# 1           2019  2019-01-08 10:56:05.000  2018-12-04 15:19:18.000
# 2           2019  2019-08-15 15:14:14.000  2019-07-16 17:00:46.000
# 3           2019  2019-01-04 11:31:47.000  2018-04-19 10:09:02.000
# 4           2019  2019-01-04 10:26:36.000  2018-08-30 09:46:37.000
#
#    CodigoRegiao Regiao  UF                                     strRazaoSocial  \
# 0             1  Norte  RO                                         CLARO S.A.
# 1             1  Norte  RO                                 BANCO DO BRASIL SA
# 2             1  Norte  RO                 CENTRAIS ELETRICAS DE RONDONIA S/A
# 3             1  Norte  RO  NOVA PROFISSIONAL CURSOS PROFISSIONALIZANTES TREI
# 4             1  Norte  RO                        OI MOVEL S.A CIP ELETRONICA
#
#                                      strNomeFantasia  Tipo    NumeroCNPJ  ...  \
# 0                                     CIP ELETRONICA     1  4.043254e+13  ...
# 1                                    BANCO DO BRASIL     1  1.910000e+02  ...
# 2                                           ENERGISA     1  5.914650e+12  ...
# 3                                             SEBRAP     1  1.311034e+13  ...
# 4  ANTIGA 14 BRASIL TELECOM CELULAR S/A- TNL PCS S/A     1  5.423963e+12  ...
#
#    CNAEPrincipal                                  DescCNAEPrincipal Atendida  \
# 0      6120501.0                            TELEFONIA MÓVEL CELULAR        N
# 1      6422100.0           BANCOS MÚLTIPLOS, COM CARTEIRA COMERCIAL        N
# 2      3514000.0                   DISTRIBUIÇÃO DE ENERGIA ELÉTRICA        N
# 3      8599604.0  TREINAMENTO EM DESENVOLVIMENTO PROFISSIONAL E ...        S
# 4      6120501.0                            TELEFONIA MÓVEL CELULAR        S
#
#    CodigoAssunto      DescricaoAssunto CodigoProblema  DescricaoProblema  \
# 0          187.0     Telefonia Celular            NaN                NaN
# 1           53.0       Banco comercial            NaN                NaN
# 2          185.0      Energia Elétrica            NaN                NaN
# 3          236.0  Cursos Livres Outros            NaN                NaN
# 4          187.0     Telefonia Celular            NaN                NaN
#
#   SexoConsumidor  FaixaEtariaConsumidor CEPConsumidor
# 0              M     entre 51 a 60 anos    76824042.0
# 1              F     entre 41 a 50 anos           NaN
# 2              M     entre 41 a 50 anos    76824322.0
# 3              M     entre 31 a 40 anos    78932000.0
# 4              M     entre 51 a 60 anos    78932000.0
#
# [5 rows x 23 columns]

# %%
reclamacoes2019.columns
# Out:
# Index(['AnoCalendario', 'DataArquivamento', 'DataAbertura', 'CodigoRegiao',
#        'Regiao', 'UF', 'strRazaoSocial', 'strNomeFantasia', 'Tipo',
#        'NumeroCNPJ', 'RadicalCNPJ', 'RazaoSocialRFB', 'NomeFantasiaRFB',
#        'CNAEPrincipal', 'DescCNAEPrincipal', 'Atendida', 'CodigoAssunto',
#        'DescricaoAssunto', 'CodigoProblema', 'DescricaoProblema',
#        'SexoConsumidor', 'FaixaEtariaConsumidor', 'CEPConsumidor'],
#       dtype='object')

# %%
reclamacoes2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17555 entries, 0 to 17554
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AnoCalendario          17555 non-null  int64
#  1   DataArquivamento       17552 non-null  object
#  2   DataAbertura           17552 non-null  object
#  3   CodigoRegiao           17555 non-null  int64
#  4   Regiao                 17555 non-null  object
#  5   UF                     17555 non-null  object
#  6   strRazaoSocial         17555 non-null  object
#  7   strNomeFantasia        14034 non-null  object
#  8   Tipo                   17555 non-null  int64
#  9   NumeroCNPJ             16028 non-null  float64
#  10  RadicalCNPJ            15974 non-null  float64
#  11  RazaoSocialRFB         14572 non-null  object
#  12  NomeFantasiaRFB        7651 non-null   object
#  13  CNAEPrincipal          14572 non-null  float64
#  14  DescCNAEPrincipal      14502 non-null  object
#  15  Atendida               17555 non-null  object
#  16  CodigoAssunto          17541 non-null  float64
#  17  DescricaoAssunto       17541 non-null  object
#  18  CodigoProblema         45 non-null     float64
#  19  DescricaoProblema      45 non-null     object
#  20  SexoConsumidor         17546 non-null  object
#  21  FaixaEtariaConsumidor  17555 non-null  object
#  22  CEPConsumidor          13921 non-null  float64
# dtypes: float64(6), int64(3), object(14)
# memory usage: 3.1+ MB

# %%
reclamacoes2020.head()
# Out:
#    AnoCalendario         DataArquivamento             DataAbertura  \
# 0           2020  2020-12-09 13:48:10.000  2019-12-26 12:28:07.000
# 1           2020  2020-08-27 12:35:41.000  2020-03-20 12:16:52.000
# 2           2020  2020-05-20 08:54:17.000  2020-03-18 13:37:12.000
# 3           2020  2020-07-30 10:25:00.000  2020-02-06 10:24:25.000
# 4           2020  2020-02-17 12:36:30.000  2020-01-21 09:36:24.000
#
#    CodigoRegiao    Regiao  UF  \
# 0             3   Sudeste  MG
# 1             2  Nordeste  RN
# 2             2  Nordeste  RN
# 3             2  Nordeste  RN
# 4             2  Nordeste  RN
#
#                                       strRazaoSocial        strNomeFantasia  \
# 0  FUNDO DE INVESTIMENTO EM DIREITOS CREDITORIOS ...                    NaN
# 1     VIRGINIA SURETY COMPANHIA DE SEGUROS DO BRASIL                    NaN
# 2                          LATAM AIRLINES GROUP S.A.      TAM LINHAS AÉREAS
# 3                 LOJAS AMERICANAS S.A.- MIDWAL MALL  LOJAS AMERIACANAS S.A
# 4                   ACBZ IMPORTACAO E COMERCIO LTDA.         ASUS NO BRASIL
#
#    Tipo    NumeroCNPJ  ...  CNAEPrincipal  \
# 0     1  2.640588e+13  ...            NaN
# 1     1  3.505295e+12  ...      6512000.0
# 2     1  3.393768e+13  ...      5111100.0
# 3     1  3.301456e+13  ...      4711302.0
# 4     1  9.509531e+12  ...      4651601.0
#
#                                    DescCNAEPrincipal Atendida  CodigoAssunto  \
# 0                                                NaN        S             53
# 1                                   SEGUROS NÃO-VIDA        N            147
# 2            TRANSPORTE AÉREO DE PASSAGEIROS REGULAR        N            157
# 3  COMÉRCIO VAREJISTA DE MERCADORIAS EM GERAL, CO...        S            102
# 4  COMÉRCIO ATACADISTA DE EQUIPAMENTOS DE INFORMÁ...        S            101
#
#                                     DescricaoAssunto CodigoProblema  \
# 0                                    Banco comercial         6834.0
# 1                                             Seguro         2548.0
# 2  Transporte ( Rodoviário, Passageiros, Cargas, ...         3727.0
# 3          Microcomputador / Produtos de Informática         2503.0
# 4  Telefone ( Convencional, Celular, Interfone, E...         2502.0
#
#                                    DescricaoProblema SexoConsumidor  \
# 0  SAC - Resolução de demandas (ausência de respo...              M
# 1                                  Produto com vício              F
# 2                   Garantia - Descumprimento, prazo              M
# 3                                  Produto com vício              F
# 4                                  Produto com vício              M
#
#    FaixaEtariaConsumidor CEPConsumidor
# 0     entre 41 a 50 anos    31742544.0
# 1     entre 51 a 60 anos    59050200.0
# 2     entre 51 a 60 anos    59076030.0
# 3     entre 41 a 50 anos    59075200.0
# 4     entre 21 a 30 anos    59147150.0
#
# [5 rows x 23 columns]

# %%
reclamacoes2020.columns
# Out:
# Index(['AnoCalendario', 'DataArquivamento', 'DataAbertura', 'CodigoRegiao',
#        'Regiao', 'UF', 'strRazaoSocial', 'strNomeFantasia', 'Tipo',
#        'NumeroCNPJ', 'RadicalCNPJ', 'RazaoSocialRFB', 'NomeFantasiaRFB',
#        'CNAEPrincipal', 'DescCNAEPrincipal', 'Atendida', 'CodigoAssunto',
#        'DescricaoAssunto', 'CodigoProblema', 'DescricaoProblema',
#        'SexoConsumidor', 'FaixaEtariaConsumidor', 'CEPConsumidor'],
#       dtype='object')

# %%
reclamacoes2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8006 entries, 0 to 8005
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AnoCalendario          8006 non-null   int64
#  1   DataArquivamento       8006 non-null   object
#  2   DataAbertura           8006 non-null   object
#  3   CodigoRegiao           8006 non-null   int64
#  4   Regiao                 8006 non-null   object
#  5   UF                     8006 non-null   object
#  6   strRazaoSocial         8006 non-null   object
#  7   strNomeFantasia        6546 non-null   object
#  8   Tipo                   8006 non-null   int64
#  9   NumeroCNPJ             7643 non-null   float64
#  10  RadicalCNPJ            7613 non-null   float64
#  11  RazaoSocialRFB         6622 non-null   object
#  12  NomeFantasiaRFB        3295 non-null   object
#  13  CNAEPrincipal          6622 non-null   float64
#  14  DescCNAEPrincipal      6576 non-null   object
#  15  Atendida               8006 non-null   object
#  16  CodigoAssunto          8006 non-null   int64
#  17  DescricaoAssunto       8006 non-null   object
#  18  CodigoProblema         7977 non-null   float64
#  19  DescricaoProblema      7977 non-null   object
#  20  SexoConsumidor         7998 non-null   object
#  21  FaixaEtariaConsumidor  8006 non-null   object
#  22  CEPConsumidor          7357 non-null   float64
# dtypes: float64(5), int64(4), object(14)
# memory usage: 1.4+ MB

# %%
reclamacoes2021.head()
# Out:
#    AnoCalendario         DataArquivamento             DataAbertura  \
# 0           2021  2021-03-03 10:19:00.000  2021-01-19 12:00:34.000
# 1           2021  2021-04-07 10:55:17.000  2021-02-19 09:33:43.000
# 2           2021  2021-03-31 09:29:57.000  2021-02-22 10:48:12.000
# 3           2021  2021-08-03 10:42:54.000  2021-06-16 11:10:37.000
# 4           2021  2021-09-21 09:22:33.000  2021-07-16 12:38:52.000
#
#    CodigoRegiao Regiao  UF                                 strRazaoSocial  \
# 0             1  Norte  PA  MULTIMARCAS ADMINISTRADORA DE CONSÓRCIOS LTDA
# 1             1  Norte  PA                           A SARAIVA SOUZA - ME
# 2             1  Norte  PA             AZUL LINHAS AÉREAS BRASILEIRAS S.A
# 3             1  Norte  PA             AZUL LINHAS AÉREAS BRASILEIRAS S.A
# 4             1  Norte  PA                       MOTOROLA INDUSTRIAL LTDA
#
#           strNomeFantasia  Tipo    NumeroCNPJ  ...  CNAEPrincipal  \
# 0  MULTIMARCAS CONSÓRCIOS     1  4.124922e+12  ...      6493000.0
# 1           MERITO CURSOS     1  2.136493e+13  ...            NaN
# 2      AZUL LINHAS AÉREAS     1  9.296295e+12  ...      5111100.0
# 3      AZUL LINHAS AÉREAS     1  9.296295e+12  ...      5111100.0
# 4                MOTOROLA     1  1.472720e+12  ...      4652400.0
#
#                                    DescCNAEPrincipal Atendida  CodigoAssunto  \
# 0  ADMINISTRAÇÃO DE CONSÓRCIOS PARA AQUISIÇÃO DE ...        N             57
# 1                                                NaN        N            236
# 2            TRANSPORTE AÉREO DE PASSAGEIROS REGULAR        N            276
# 3            TRANSPORTE AÉREO DE PASSAGEIROS REGULAR        N            276
# 4  COMÉRCIO ATACADISTA DE COMPONENTES ELETRÔNICOS...        N            101
#
#                                     DescricaoAssunto CodigoProblema  \
# 0  Consórcio de Automóveis ou Automotores, Utilit...         1307.0
# 1                               Cursos Livres Outros         5369.0
# 2  Agências e Operadoras de viagens (pacotes turí...         5157.0
# 3  Agências e Operadoras de viagens (pacotes turí...         5760.0
# 4  Telefone ( Convencional, Celular, Interfone, E...            NaN
#
#                           DescricaoProblema SexoConsumidor  \
# 0                  Desistência de consorcio              M
# 1                 Cobrança indevida/abusiva              F
# 2   Recusa injustificada em prestar serviço              F
# 3  Contrato - Rescisão/alteração unilateral              F
# 4                                       NaN              F
#
#    FaixaEtariaConsumidor CEPConsumidor
# 0     entre 21 a 30 anos    68000001.0
# 1     entre 31 a 40 anos    68143000.0
# 2     entre 31 a 40 anos    68040020.0
# 3     entre 21 a 30 anos    68020620.0
# 4     entre 31 a 40 anos           NaN
#
# [5 rows x 23 columns]

# %%
reclamacoes2021.columns
# Out:
# Index(['AnoCalendario', 'DataArquivamento', 'DataAbertura', 'CodigoRegiao',
#        'Regiao', 'UF', 'strRazaoSocial', 'strNomeFantasia', 'Tipo',
#        'NumeroCNPJ', 'RadicalCNPJ', 'RazaoSocialRFB', 'NomeFantasiaRFB',
#        'CNAEPrincipal', 'DescCNAEPrincipal', 'Atendida', 'CodigoAssunto',
#        'DescricaoAssunto', 'CodigoProblema', 'DescricaoProblema',
#        'SexoConsumidor', 'FaixaEtariaConsumidor', 'CEPConsumidor'],
#       dtype='object')

# %%
reclamacoes2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9007 entries, 0 to 9006
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AnoCalendario          9007 non-null   int64
#  1   DataArquivamento       9005 non-null   object
#  2   DataAbertura           9005 non-null   object
#  3   CodigoRegiao           9007 non-null   int64
#  4   Regiao                 9007 non-null   object
#  5   UF                     9007 non-null   object
#  6   strRazaoSocial         9007 non-null   object
#  7   strNomeFantasia        7215 non-null   object
#  8   Tipo                   9007 non-null   int64
#  9   NumeroCNPJ             8411 non-null   float64
#  10  RadicalCNPJ            8378 non-null   float64
#  11  RazaoSocialRFB         7129 non-null   object
#  12  NomeFantasiaRFB        3510 non-null   object
#  13  CNAEPrincipal          7129 non-null   float64
#  14  DescCNAEPrincipal      7105 non-null   object
#  15  Atendida               9007 non-null   object
#  16  CodigoAssunto          9007 non-null   int64
#  17  DescricaoAssunto       9007 non-null   object
#  18  CodigoProblema         9002 non-null   float64
#  19  DescricaoProblema      9002 non-null   object
#  20  SexoConsumidor         9002 non-null   object
#  21  FaixaEtariaConsumidor  9007 non-null   object
#  22  CEPConsumidor          7541 non-null   float64
# dtypes: float64(5), int64(4), object(14)
# memory usage: 1.6+ MB

# %%
# concatenar todos os dataframes
todas_reclamacoes = pd.concat([newreclamacoes2017, reclamacoes2018, reclamacoes2019, reclamacoes2020, reclamacoes2021], ignore_index=True)

# %%
todas_reclamacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115922 entries, 0 to 115921
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   AnoCalendario          115922 non-null  int64
#  1   DataArquivamento       115897 non-null  object
#  2   DataAbertura           115910 non-null  object
#  3   CodigoRegiao           115922 non-null  int64
#  4   Regiao                 115922 non-null  object
#  5   UF                     115922 non-null  object
#  6   strRazaoSocial         115919 non-null  object
#  7   strNomeFantasia        95801 non-null   object
#  8   Tipo                   115922 non-null  int64
#  9   NumeroCNPJ             109663 non-null  float64
#  10  RadicalCNPJ            109426 non-null  float64
#  11  RazaoSocialRFB         100314 non-null  object
#  12  NomeFantasiaRFB        49181 non-null   object
#  13  CNAEPrincipal          100314 non-null  float64
#  14  DescCNAEPrincipal      99750 non-null   object
#  15  Atendida               115922 non-null  object
#  16  CodigoAssunto          115908 non-null  float64
#  17  DescricaoAssunto       115908 non-null  object
#  18  CodigoProblema         50482 non-null   float64
#  19  DescricaoProblema      50482 non-null   object
#  20  SexoConsumidor         115885 non-null  object
#  21  FaixaEtariaConsumidor  115922 non-null  object
#  22  CEPConsumidor          103612 non-null  float64
# dtypes: float64(6), int64(3), object(14)
# memory usage: 20.3+ MB

# %%
todas_reclamacoes.shape
# Out:
# (115922, 23)

# %%
colunas_desejadas = ['AnoCalendario', 'DataArquivamento', 'DataAbertura',
                     'Regiao', 'UF', 'strRazaoSocial', 'Atendida',
                     'SexoConsumidor', 'FaixaEtariaConsumidor']

novo_dataframe_desejado = todas_reclamacoes[colunas_desejadas].copy()
novo_dataframe_desejado.head()
# Out:
#    AnoCalendario         DataArquivamento             DataAbertura   Regiao  \
# 0           2017  2017-10-05 09:48:39.000  2017-07-27 14:43:37.000  Sudeste
# 1           2017  2017-12-12 12:35:53.000  2017-07-31 16:03:45.000  Sudeste
# 2           2017  2017-12-12 12:40:07.000  2017-08-04 10:55:48.000  Sudeste
# 3           2017  2017-10-26 14:07:56.000  2017-07-19 14:48:25.000  Sudeste
# 4           2017  2017-12-04 09:51:45.000  2017-07-21 11:00:06.000  Sudeste
#
#    UF                                     strRazaoSocial Atendida  \
# 0  SP                                  ITAÚ UNIBANCO S/A        S
# 1  SP                                          CLARO S/A        S
# 2  SP  ELETROPAULO METROPOLITANA ELETRICIDADE DE S PAULO        N
# 3  SP                            GNN GARAGENS LTDA - EPP        N
# 4  SP                                          CLARO S/A        S
#
#   SexoConsumidor FaixaEtariaConsumidor
# 0              F    entre 31 a 40 anos
# 1              M       mais de 70 anos
# 2              F    entre 31 a 40 anos
# 3              M    entre 31 a 40 anos
# 4              M    entre 41 a 50 anos

# %%
novo_dataframe_desejado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115922 entries, 0 to 115921
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   AnoCalendario          115922 non-null  int64
#  1   DataArquivamento       115897 non-null  object
#  2   DataAbertura           115910 non-null  object
#  3   Regiao                 115922 non-null  object
#  4   UF                     115922 non-null  object
#  5   strRazaoSocial         115919 non-null  object
#  6   Atendida               115922 non-null  object
#  7   SexoConsumidor         115885 non-null  object
#  8   FaixaEtariaConsumidor  115922 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 8.0+ MB

# %%
novo_dataframe_desejado.shape
# Out:
# (115922, 9)

# %% [markdown]
# # 1)	Análise dos dados:

# %% [markdown]
# 1 - Existe alguma sazonalidade na data de abertura de uma reclamação? Ou seja, mais consumidores abrem reclamações em determinada época do ano?

# %% [markdown]
# 2 - Qual o tempo médio de uma reclamação ativa (da abertura até a data de fechamento)?

# %% [markdown]
# 3 - O número de reclamações varia de acordo com a região? e de acordo com o estado? E se ponderarmos pela população média do estado?

# %%
contagem_reclamacoes_por_regiao = novo_dataframe_desejado['Regiao'].value_counts()
print(contagem_reclamacoes_por_regiao)
# Out:
# Regiao
# Sudeste         55942
# Centro-oeste    32053
# Nordeste        14201
# Norte            7749
# Sul              5977
# Name: count, dtype: int64

# %%
contagem_reclamacoes_por_estado = novo_dataframe_desejado['UF'].value_counts()
print(contagem_reclamacoes_por_estado)
# Out:
# UF
# SP    40999
# GO    17259
# MG     8550
# RN     8128
# MT     7822
# MS     6972
# RO     6195
# SC     4920
# RJ     3612
# ES     2781
# PI     2153
# CE     1982
# PB     1486
# PA      987
# PR      875
# TO      567
# MA      216
# PE      211
# RS      182
# BA       25
# Name: count, dtype: int64

# %%
populacao_por_estado = {
    'AC': 906000, 'AP': 877000, 'AM': 4270000, 'PA': 8770000,
    'RO': 1810000, 'RR': 652000, 'TO': 1600000, 'AL': 3370000,
    'BA': 14980000, 'CE': 9270000, 'MA': 7160000, 'PB': 4050000,
    'PE': 9670000, 'PI': 3290000, 'RN': 3560000, 'SE': 2340000,
    'ES': 4110000, 'MG': 21410000, 'RJ': 17460000, 'SP': 46650000,
    'PR': 11580000, 'RS': 11320000, 'SC': 7330000, 'DF': 3090000,
    'GO': 7210000, 'MT': 3570000, 'MS': 2800000
}

# %%
novo_dataframe_desejado['Populacao'] = novo_dataframe_desejado['UF'].map(populacao_por_estado)
novo_dataframe_desejado.head()
# Out:
#    AnoCalendario         DataArquivamento             DataAbertura   Regiao  \
# 0           2017  2017-10-05 09:48:39.000  2017-07-27 14:43:37.000  Sudeste
# 1           2017  2017-12-12 12:35:53.000  2017-07-31 16:03:45.000  Sudeste
# 2           2017  2017-12-12 12:40:07.000  2017-08-04 10:55:48.000  Sudeste
# 3           2017  2017-10-26 14:07:56.000  2017-07-19 14:48:25.000  Sudeste
# 4           2017  2017-12-04 09:51:45.000  2017-07-21 11:00:06.000  Sudeste
#
#    UF                                     strRazaoSocial Atendida  \
# 0  SP                                  ITAÚ UNIBANCO S/A        S
# 1  SP                                          CLARO S/A        S
# 2  SP  ELETROPAULO METROPOLITANA ELETRICIDADE DE S PAULO        N
# 3  SP                            GNN GARAGENS LTDA - EPP        N
# 4  SP                                          CLARO S/A        S
#
#   SexoConsumidor FaixaEtariaConsumidor  Populacao
# 0              F    entre 31 a 40 anos   46650000
# 1              M       mais de 70 anos   46650000
# 2              F    entre 31 a 40 anos   46650000
# 3              M    entre 31 a 40 anos   46650000
# 4              M    entre 41 a 50 anos   46650000

# %%
reclamacoes_por_estado = novo_dataframe_desejado.groupby('UF')['UF'].count().reset_index(name='NumReclamacoes')
reclamacoes_por_estado
# Out:
#     UF  NumReclamacoes
# 0   BA              25
# 1   CE            1982
# 2   ES            2781
# 3   GO           17259
# 4   MA             216
# 5   MG            8550
# 6   MS            6972
# 7   MT            7822
# 8   PA             987
# 9   PB            1486
# 10  PE             211
# 11  PI            2153
# 12  PR             875
# 13  RJ            3612
# 14  RN            8128
# 15  RO            6195
# 16  RS             182
# 17  SC            4920
# 18  SP           40999
# 19  TO             567

# %%
reclamacoes_por_estado['Populacao'] = reclamacoes_por_estado['UF'].map(populacao_por_estado)
reclamacoes_por_estado
# Out:
#     UF  NumReclamacoes  Populacao  ReclamacoesPonderadas
# 0   BA              25   14980000               0.000002
# 1   CE            1982    9270000               0.000214
# 2   ES            2781    4110000               0.000677
# 3   GO           17259    7210000               0.002394
# 4   MA             216    7160000               0.000030
# 5   MG            8550   21410000               0.000399
# 6   MS            6972    2800000               0.002490
# 7   MT            7822    3570000               0.002191
# 8   PA             987    8770000               0.000113
# 9   PB            1486    4050000               0.000367
# 10  PE             211    9670000               0.000022
# 11  PI            2153    3290000               0.000654
# 12  PR             875   11580000               0.000076
# 13  RJ            3612   17460000               0.000207
# 14  RN            8128    3560000               0.002283
# 15  RO            6195    1810000               0.003423
# 16  RS             182   11320000               0.000016
# 17  SC            4920    7330000               0.000671
# 18  SP           40999   46650000               0.000879
# 19  TO             567    1600000               0.000354

# %%
reclamacoes_por_estado['ReclamacoesPonderadas'] = reclamacoes_por_estado['NumReclamacoes'] / reclamacoes_por_estado['Populacao']
print(reclamacoes_por_estado)

# %% [markdown]
# 4 - Quais as empresas que receberam mais reclamações dos consumidores?E por região e estado?

# %% [markdown]
# ## 2)	Modelagem: Prevendo o tempo de uma reclamação ativa

# %% [markdown]
# O time de negócios gostaria que a sua equipe fizesse um modelo de regressão para estimar qual será o tempo médio de uma reclamação ativa. Com isso.

# %% [markdown]
# 1- Quais variáveis podem estar mais correlacionadas com o tempo de uma reclamação ativa?

# %% [markdown]
# 2- Construa variáveis que podem estar correlacionadas com o tempo de uma reclamação ativa a partir dos dados: Exemplo: crie variáveis dummy referentes ao período do ano ; região

# %% [markdown]
# 3- Analise a correlação das variáveis.

# %% [markdown]
# 4 - Construa um modelo de regressão linear em que queremos estimar o tempo de uma reclamação ativa.
